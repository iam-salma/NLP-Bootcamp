# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

wv['king']
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
import pandas as pd
messages=pd.read_csv('../smsspamcollection/SMSSpamCollection', sep='\t',names=["label","message"])
messages
# Out:
#      label                                            message
# 0      ham  Go until jurong point, crazy.. Available only ...
# 1      ham                      Ok lar... Joking wif u oni...
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3      ham  U dun say so early hor... U c already then say...
# 4      ham  Nah I don't think he goes to usf, he lives aro...
# ...    ...                                                ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...
# 5568   ham               Will ü b going to esplanade fr home?
# 5569   ham  Pity, * was in mood for that. So...any other s...
# 5570   ham  The guy did some bitching but I acted like i'd...
# 5571   ham                         Rofl. Its true to its name
#
# [5572 rows x 2 columns]

# %%
messages.shape
# Out:
# (5572, 2)

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
import re
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\salma\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk import word_tokenize
corpus = []
for i in range(len(messages)):
    review = re.sub(r"[^a-zA-Z0-9\s]", "", messages['message'][i]).lower()
    review = word_tokenize(review)
    review = [lemmatizer.lemmatize(word) for word in review]
    review = ' '.join(review)
    corpus.append(review)

# %%
[[i,j,k] for i,j,k in zip(list(map(len,corpus)),corpus, messages['message']) if i<1]
# Out:
# [[0, '', ':) '], [0, '', ':-) :-)']]

# %%
corpus[0:4]
# Out:
# ['go until jurong point crazy available only in bugis n great world la e buffet cine there got amore wat',
#  'ok lar joking wif u oni',
#  'free entry in 2 a wkly comp to win fa cup final tkts 21st may 2005 text fa to 87121 to receive entry questionstd txt ratetcs apply 08452810075over18s',
#  'u dun say so early hor u c already then say']

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
sentences=[]
for sent in corpus:
    sent_token=sent_tokenize(sent)
    for token in sent_token:
        sentences.append(simple_preprocess(token))

# %%
sentences
# Out:
# [['go',
#   'until',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'only',
#   'in',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'there',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni'],
#  ['free',
#   'entry',
#   'in',
#   'wkly',
#   'comp',
#   'to',
#   'win',
#   'fa',
#   'cup',
#   'final',
#   'tkts',
#   'st',
#   'may',
#   'text',
#   'fa',
#   'to',
#   'to',
#   'receive',
#   'entry',
#   'questionstd',
#   'txt',
#   'ratetcs',
#   'apply',
#   'over'],
#  ['dun', 'say', 'so', 'early', 'hor', 'already', 'then', 'say'],
#  ['nah',
#   'dont',
#   'think',
#   'he',
#   'go',
#   'to',
#   'usf',
#   'he',
#   'life',
#   'around',
#   'here',
#   'though'],
#  ['freemsg',
#   'hey',
#   'there',
#   'darling',
#   'it',
#   'been',
#   'week',
#   'now',
#   'and',
#   'no',
#   'word',
#   'back',
#   'id',
#   'like',
#   'some',
#   'fun',
#   'you',
#   'up',
#   'for',
#   'it',
# ...

# %%
import gensim

## Lets train Word2vec from scratch
model=gensim.models.Word2Vec(sentences)

# %%
## To Get All the Vocabulary
model.wv.index_to_key
# Out:
# ['to',
#  'you',
#  'the',
#  'and',
#  'it',
#  'is',
#  'in',
#  'me',
#  'my',
#  'for',
#  'your',
#  'of',
#  'call',
#  'have',
#  'on',
#  'that',
#  'are',
#  'now',
#  'im',
#  'not',
#  'so',
#  'but',
#  'or',
#  'can',
#  'at',
#  'get',
#  'do',
#  'ur',
#  'be',
#  'will',
#  'if',
#  'with',
#  'just',
#  'no',
#  'we',
#  'this',
#  'go',
#  'up',
#  'dont',
#  'when',
#  'free',
#  'from',
#  'ok',
#  'ltgt',
#  'all',
#  'out',
#  'know',
#  'how',
#  'what',
#  'day',
#  'got',
#  'come',
#  'like',
#  'ill',
#  'am',
#  'good',
#  'wa',
#  'then',
#  'time',
#  'there',
#  'he',
#  'only',
#  'text',
#  'want',
#  'love',
#  'send',
#  'need',
#  'one',
#  'by',
#  'going',
#  'today',
#  'txt',
#  'about',
#  'home',
#  'lor',
#  'stop',
#  'see',
#  'sorry',
#  'still',
#  'mobile',
#  'back',
#  'our',
#  'think',
#  'reply',
#  'tell',
#  'take',
#  'phone',
#  'week',
#  'new',
#  'well',
#  'hi',
#  'later',
#  'da',
#  'ha',
#  'she',
#  'been',
# ...

# %%
model.corpus_count
# Out:
# 5570

# %%
model.epochs
# Out:
# 5

# %%
model.wv.similar_by_word('good')
# Out:
# [('great', 0.9990028738975525),
#  ('love', 0.9989824891090393),
#  ('how', 0.9989509582519531),
#  ('day', 0.9989371299743652),
#  ('hope', 0.9988108277320862),
#  ('morning', 0.9987794160842896),
#  ('well', 0.9987261295318604),
#  ('did', 0.9986915588378906),
#  ('make', 0.9986792206764221),
#  ('where', 0.9986752271652222)]

# %%
model.wv['good'].shape
# Out:
# (100,)

# %%
sentences[0:2]
# Out:
# [['go',
#   'until',
#   'jurong',
#   'point',
#   'crazy',
#   'available',
#   'only',
#   'in',
#   'bugis',
#   'great',
#   'world',
#   'la',
#   'buffet',
#   'cine',
#   'there',
#   'got',
#   'amore',
#   'wat'],
#  ['ok', 'lar', 'joking', 'wif', 'oni']]

# %%
def avg_word2vec(sentence):
    # remove out-of-vocabulary words
    #sent = [word for word in doc if word in model.wv.index_to_key]
    #print(sent)
    
    return np.mean([model.wv[word] for word in sentence if word in model.wv.index_to_key],axis=0)
                #or [np.zeros(len(model.wv.index_to_key))], axis=0)

# %%
from tqdm import tqdm

# %%
#apply for the entire sentences
import numpy as np
X=[]
for i in tqdm(range(len(sentences))):
    X.append(avg_word2vec(sentences[i]))
# Out:
# 100%|██████████| 5570/5570 [00:00<00:00, 6206.44it/s]

# %%
X[0:2]
# Out:
# [array([-0.14418438,  0.2780201 ,  0.14765288,  0.07243586,  0.10192553,
#         -0.4324702 ,  0.24794006,  0.566939  , -0.1806996 , -0.24884744,
#         -0.05186125, -0.38832328, -0.00557207,  0.1488985 ,  0.07632635,
#         -0.15383019,  0.15112421, -0.24115202, -0.09666879, -0.48704657,
#          0.20243044,  0.22007775,  0.177808  , -0.13020279,  0.00352161,
#         -0.02285952, -0.22595601, -0.1963304 , -0.30249733,  0.12932612,
#          0.27802715,  0.01295363,  0.14977804, -0.23462363, -0.02099985,
#          0.3966801 ,  0.03104406, -0.16016586, -0.1064309 , -0.40423596,
#         -0.02190626, -0.24097171, -0.12687612,  0.05937417,  0.2390478 ,
#         -0.0700127 , -0.21107922, -0.13352658,  0.22913153,  0.15271783,
#          0.17463157, -0.27410743, -0.17546946, -0.00114136, -0.14030626,
#          0.13764317,  0.11745772, -0.06427706, -0.3439373 ,  0.14805315,
#          0.0635274 ,  0.07017767, -0.08776589, -0.11784094, -0.33974788,
# ...

# %%
len(X)
# Out:
# 5570

# %%
len(sentences)
# Out:
# 5570

# %%
##independent Features
X_new=np.array(X, dtype=object)

# %%
X_new[0:2]
# Out:
# array([array([-0.14418438,  0.2780201 ,  0.14765288,  0.07243586,  0.10192553,
#               -0.4324702 ,  0.24794006,  0.566939  , -0.1806996 , -0.24884744,
#               -0.05186125, -0.38832328, -0.00557207,  0.1488985 ,  0.07632635,
#               -0.15383019,  0.15112421, -0.24115202, -0.09666879, -0.48704657,
#                0.20243044,  0.22007775,  0.177808  , -0.13020279,  0.00352161,
#               -0.02285952, -0.22595601, -0.1963304 , -0.30249733,  0.12932612,
#                0.27802715,  0.01295363,  0.14977804, -0.23462363, -0.02099985,
#                0.3966801 ,  0.03104406, -0.16016586, -0.1064309 , -0.40423596,
#               -0.02190626, -0.24097171, -0.12687612,  0.05937417,  0.2390478 ,
#               -0.0700127 , -0.21107922, -0.13352658,  0.22913153,  0.15271783,
#                0.17463157, -0.27410743, -0.17546946, -0.00114136, -0.14030626,
#                0.13764317,  0.11745772, -0.06427706, -0.3439373 ,  0.14805315,
# ...

# %%
X_new.shape
# Out:
# (5570,)

# %%
messages.shape
# Out:
# (5572, 2)

# %%
X_new[1].shape
# Out:
# (100,)

# %%
## Dependent Features
## Output Features
y = messages[list(map(lambda x: len(x)>0 ,corpus))] #  filter messages and keep only those where corpus[i] is non-empty.
y=pd.get_dummies(y['label'])
print(y.astype(int))
y=y.iloc[:,1].values.astype(int)
# Out:
#       ham  spam
# 0       1     0
# 1       1     0
# 2       0     1
# 3       1     0
# 4       1     0
# ...   ...   ...
# 5567    0     1
# 5568    1     0
# 5569    1     0
# 5570    1     0
# 5571    1     0
#
# [5570 rows x 2 columns]

# %%
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
y.shape
# Out:
# (5570,)

# %%
X_new[0].reshape(1,-1).shape
# Out:
# (1, 100)

# %%
## this is the final independent features
df=pd.DataFrame()
df_rows = []
for i in range(len(X)):
    df_rows.append(pd.DataFrame(X_new[i].reshape(1,-1)))
df = pd.concat(df_rows, ignore_index=True)

# %%
df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.144184  0.278020  0.147653  0.072436  0.101926 -0.432470  0.247940
# 1 -0.124052  0.242586  0.123540  0.059988  0.093007 -0.376028  0.214889
# 2 -0.171251  0.318800  0.189212  0.063936  0.135092 -0.488667  0.248346
# 3 -0.199875  0.388103  0.197504  0.109884  0.140247 -0.603020  0.354807
# 4 -0.171176  0.324699  0.173062  0.102868  0.117984 -0.504272  0.293567
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.566939 -0.180700 -0.248847  ...  0.296716  0.216263 -0.003991  0.117940
# 1  0.494231 -0.145683 -0.213555  ...  0.247143  0.187100 -0.010302  0.103121
# 2  0.608481 -0.171542 -0.289046  ...  0.344504  0.224658  0.034667  0.099827
# 3  0.792814 -0.248855 -0.350100  ...  0.403445  0.300697 -0.018184  0.178907
# 4  0.671895 -0.214960 -0.290956  ...  0.338257  0.250632 -0.016558  0.147155
#
#          94        95        96        97        98        99
# ...

# %%
df['Output']=y

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.144184  0.278020  0.147653  0.072436  0.101926 -0.432470  0.247940
# 1 -0.124052  0.242586  0.123540  0.059988  0.093007 -0.376028  0.214889
# 2 -0.171251  0.318800  0.189212  0.063936  0.135092 -0.488667  0.248346
# 3 -0.199875  0.388103  0.197504  0.109884  0.140247 -0.603020  0.354807
# 4 -0.171176  0.324699  0.173062  0.102868  0.117984 -0.504272  0.293567
#
#           7         8         9  ...        91        92        93        94  \
# 0  0.566939 -0.180700 -0.248847  ...  0.216263 -0.003991  0.117940  0.494685
# 1  0.494231 -0.145683 -0.213555  ...  0.187100 -0.010302  0.103121  0.428582
# 2  0.608481 -0.171542 -0.289046  ...  0.224658  0.034667  0.099827  0.561481
# 3  0.792814 -0.248855 -0.350100  ...  0.300697 -0.018184  0.178907  0.682621
# 4  0.671895 -0.214960 -0.290956  ...  0.250632 -0.016558  0.147155  0.571286
#
#          95        96        97        98        99  Output
# ...

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 96        0
# 97        0
# 98        0
# 99        0
# Output    0
# Length: 101, dtype: int64

# %%
## Independent Features
X=df.drop('Output', axis=1)
## dependent Feature
y=df['Output']

# %%
## Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20)

# %%
y_train
# Out:
# 2844    0
# 4980    0
# 3313    0
# 5566    0
# 3643    0
#        ..
# 2576    0
# 4573    1
# 4791    0
# 5472    0
# 2731    0
# Name: Output, Length: 4440, dtype: int32

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    AdaBoostClassifier,
    BaggingClassifier,
    ExtraTreesClassifier,
    GradientBoostingClassifier,
    RandomForestClassifier
)

classifiers = {
    "Naive Bayes": GaussianNB(),
    "Logistic Regression": LogisticRegression(class_weight='balanced', max_iter=1000),
    "Random Forest": RandomForestClassifier(n_estimators=200, class_weight='balanced', random_state=42),
    "SVM": LinearSVC(class_weight='balanced'),
    "KNN": KNeighborsClassifier(n_neighbors=5),
    "Decision Tree": DecisionTreeClassifier(class_weight='balanced', random_state=42),
    "Extra Trees": ExtraTreesClassifier(n_estimators=100, class_weight='balanced', random_state=42),
    "AdaBoost": AdaBoostClassifier(n_estimators=100, random_state=42),
    "Bagging": BaggingClassifier(n_estimators=100, random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(n_estimators=100),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)
}

# %%
from sklearn.metrics import accuracy_score, classification_report

scores = []
best_model = None
best_score = 0

for name, clf in classifiers.items():
    print(f"\n🧠 {name}")
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred)
    print("Accuracy:", accuracy_score(y_test, y_pred))
    print(classification_report(y_test, y_pred))
    if acc > best_score:
        best_score = acc
        best_model = (name, clf)

print("\n🏆 Best Model:")
print(f"{best_model[0]} with accuracy: {best_score:.4f}")
# Out:
# 🧠 Naive Bayes
# Accuracy: 0.8622862286228623
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.91       946
#            1       0.52      0.84      0.64       165
#
#     accuracy                           0.86      1111
#    macro avg       0.75      0.85      0.78      1111
# weighted avg       0.90      0.86      0.87      1111
#
#
# 🧠 Logistic Regression
# Accuracy: 0.9126912691269127
#               precision    recall  f1-score   support
#
#            0       0.98      0.92      0.95       946
#            1       0.66      0.87      0.75       165
#
#     accuracy                           0.91      1111
#    macro avg       0.82      0.89      0.85      1111
# weighted avg       0.93      0.91      0.92      1111
#
#
# 🧠 Random Forest
# Accuracy: 0.9693969396939695
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       946
# ...

# %%
best_model[1].fit(X_train,y_train)
# Out:
# ExtraTreesClassifier(class_weight='balanced', random_state=42)

# %%
y_pred=best_model[1].predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report
print(accuracy_score(y_test,y_pred))
# Out:
# 0.9711971197119712

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98       946
#            1       0.97      0.83      0.90       165
#
#     accuracy                           0.97      1111
#    macro avg       0.97      0.91      0.94      1111
# weighted avg       0.97      0.97      0.97      1111

# %%
test_msg = "Congratulations! You've been selected to receive a free iPhone! Click here to claim your prize now!"
test_msg = re.sub(r"[^a-zA-Z0-9\s]", "", test_msg).lower()
words = word_tokenize(test_msg)
words = [lemmatizer.lemmatize(word) for word in words if word.isalpha()]
clean_msg = ' '.join(words)
sentences = sent_tokenize(clean_msg)
tokens = [simple_preprocess(sent) for sent in sentences][0]
tokens
# Out:
# ['congratulation',
#  'youve',
#  'been',
#  'selected',
#  'to',
#  'receive',
#  'free',
#  'iphone',
#  'click',
#  'here',
#  'to',
#  'claim',
#  'your',
#  'prize',
#  'now']

# %%
input_vector = avg_word2vec(tokens).reshape(1, -1)
input_vector.shape
# Out:
# (1, 100)

# %%
result = best_model[1].predict(input_vector)[0]
print(result)
print("Spam" if result == 1 else "Ham")
# Out:
# 1
# Spam

# %%
test_msg = "Hey, are we still meeting at 5 PM today? Let me know if anything changes."
test_msg = re.sub('[^a-zA-Z]', ' ', test_msg).lower()
words = word_tokenize(test_msg)
words = [lemmatizer.lemmatize(word) for word in words if word.isalpha()]
clean_msg = ' '.join(words)
sentences = sent_tokenize(clean_msg)
tokens = [simple_preprocess(sent) for sent in sentences][0]
input_vector = avg_word2vec(tokens).reshape(1, -1)
result = best_model[1].predict(input_vector)[0]
print(result)
print("Spam" if result == 1 else "Ham")
# Out:
# 0
# Ham
